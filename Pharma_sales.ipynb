# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholas-ooko/my-first-repository/blob/main/Pharma_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from io import StringIO

csv_text = """Date,Product,Category,Sales,Region
2024-01-01,Panadol,Pharma,12000,Nairobi
2024-01-02,Amoxil,Pharma,34000,Kisumu
2024-01-03,Insulin,Pharma,67000,Nairobi
2024-01-04,Vitamin C,OTC,15000,Mombasa
2024-01-05,Syrup,OTC,22000,Nairobi
2024-01-06,Panadol,Pharma,18000,Kisumu
2024-01-07,Insulin,Pharma,72000,Nairobi
2024-01-08,Vitamin C,OTC,14000,Kisumu
2024-01-09,Syrup,OTC,26000,Mombasa
2024-01-10,Amoxil,Pharma,39000,Nairobi
2024-01-11,Panadol,Pharma,16000,Mombasa
2024-01-12,Insulin,Pharma,81000,Nairobi
2024-01-13,Vitamin C,OTC,13000,Nairobi
2024-01-14,Syrup,OTC,24000,Kisumu
2024-01-15,Amoxil,Pharma,42000,Mombasa"""
df = pd.read_csv(StringIO(csv_text))
df.head(), df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      15 non-null     object
#  1   Product   15 non-null     object
#  2   Category  15 non-null     object
#  3   Sales     15 non-null     int64
#  4   Region    15 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 732.0+ bytes
# (         Date    Product Category  Sales   Region
#  0  2024-01-01    Panadol   Pharma  12000  Nairobi
#  1  2024-01-02     Amoxil   Pharma  34000   Kisumu
#  2  2024-01-03    Insulin   Pharma  67000  Nairobi
#  3  2024-01-04  Vitamin C      OTC  15000  Mombasa
#  4  2024-01-05      Syrup      OTC  22000  Nairobi,
#  None)

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      15 non-null     object
#  1   Product   15 non-null     object
#  2   Category  15 non-null     object
#  3   Sales     15 non-null     int64
#  4   Region    15 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 732.0+ bytes
#               Sales
# count     15.000000
# mean   33000.000000
# std    22975.141846
# min    12000.000000
# 25%    15500.000000
# 50%    24000.000000
# 75%    40500.000000
# max    81000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      15 non-null     object
#  1   Product   15 non-null     object
#  2   Category  15 non-null     object
#  3   Sales     15 non-null     int64
#  4   Region    15 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 732.0+ bytes

# %% [markdown]
# ##Simple Analysis

# %%
df.groupby("Region")["Sales"].sum()
df.groupby("Product")["Sales"].sum()
# Out:
# Product
# Amoxil       115000
# Insulin      220000
# Panadol       46000
# Syrup         72000
# Vitamin C     42000
# Name: Sales, dtype: int64

# %%
df.groupby("Region")["Sales"].sum()
# Out:
# Region
# Kisumu      90000
# Mombasa     99000
# Nairobi    306000
# Name: Sales, dtype: int64

# %%
df.groupby(["Product", "Region"])["Sales"].sum()
# Out:
# Product    Region
# Amoxil     Kisumu      34000
#            Mombasa     42000
#            Nairobi     39000
# Insulin    Nairobi    220000
# Panadol    Kisumu      18000
#            Mombasa     16000
#            Nairobi     12000
# Syrup      Kisumu      24000
#            Mombasa     26000
#            Nairobi     22000
# Vitamin C  Kisumu      14000
#            Mombasa     15000
#            Nairobi     13000
# Name: Sales, dtype: int64

# %%
import matplotlib.pyplot as plt
df.groupby("Region")["Sales"].sum().plot(kind="bar")
plt.show()
